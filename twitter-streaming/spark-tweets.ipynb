# %%
data=sqlContext.sql("select * from spark_project_csv")
data.show()

# %%
data.printSchema()

# %%
data.count()

# %%
data.head()

# %%
data.select('_c4','_c9').show(10)

# %%
data.groupBy("_c4").count().show()
